# %% [markdown]
# Lendo os Dados

# %%
path_json = "../data_raw/dados_empresaA.json"

# %%
import json

# %%
with open(path_json, 'r') as file:
    dados_json = json.load(file)

# %%
print(type(dados_json))
print(type(dados_json[0]))
# Out:
# <class 'list'>
# <class 'dict'>

# %%
dados_json[0]
# Out:
# {'Nome do Produto': 'Blush em pó',
#  'Categoria do Produto': 'Eletrodomésticos',
#  'Preço do Produto (R$)': 79.41,
#  'Quantidade em Estoque': 7,
#  'Filial': 'Filial 7'}

# %%
path_csv = "../data_raw/dados_empresaB.csv"

# %%
with open(path_csv, 'r') as file:
    dados_csv = file.readlines()

# %%
import csv

# %%
dados_csv = []
with open(path_csv, 'r') as file:
    spamreader = csv.reader(file, delimiter=',')
    for row in spamreader:
        dados_csv.append(row)

# %%
dados_csv[0][0]
# Out:
# 'Nome do Item'

# %%
print(type(dados_csv))
print(type(dados_csv[0]))
# Out:
# <class 'list'>
# <class 'list'>

# %%
dados_csv = []
with open(path_csv, 'r') as file:
    spamreader = csv.DictReader(file, delimiter=',')
    for row in spamreader:
        dados_csv.append(row)

# %%
dados_csv[0]
# Out:
# {'Nome do Item': 'Lápis de sobrancelha',
#  'Classificação do Produto': 'Roupas',
#  'Valor em Reais (R$)': '55.17',
#  'Quantidade em Estoque': '62',
#  'Nome da Loja': 'Filial 1',
#  'Data da Venda': '2023-04-13 18:58:06.794203'}

# %%
nome_colunas_json = list(dados_json[0].keys())
print(f"Colunas: {nome_colunas_json} \nn° de colunas: {len(nome_colunas_json)}")
# Out:
# Colunas: ['Nome do Produto', 'Categoria do Produto', 'Preço do Produto (R$)', 'Quantidade em Estoque', 'Filial']
# n° de colunas: 5

# %%
nome_colunas_csv = list(dados_csv[0].keys())
print(f"Colunas: {nome_colunas_csv} \nn° de colunas: {len(nome_colunas_csv)}")
# Out:
# Colunas: ['Nome do Item', 'Classificação do Produto', 'Valor em Reais (R$)', 'Quantidade em Estoque', 'Nome da Loja', 'Data da Venda']
# n° de colunas: 6

# %%
key_mapping = {'Nome do Item': 'Nome do Produto',
               'Classificação do Produto': 'Categoria do Produto',
               'Valor em Reais (R$)': 'Preço do Produto (R$)',
               'Quantidade em Estoque': 'Quantidade em Estoque',
               'Nome da Loja': 'Filial',
               'Data da Venda': 'Data da Venda'
               }
key_mapping
# Out:
# {'Nome do Item': 'Nome do Produto',
#  'Classificação do Produto': 'Categoria do Produto',
#  'Valor em Reais (R$)': 'Preço do Produto (R$)',
#  'Quantidade em Estoque': 'Quantidade em Estoque',
#  'Nome da Loja': 'Filial',
#  'Data da Venda': 'Data da Venda'}

# %%
new_dados_csv = []

for old_dict in dados_csv:
    dict_temp = {}
    for old_key, value in old_dict.items():
        dict_temp[key_mapping[old_key]] = value
    new_dados_csv.append(dict_temp)

# new_dados_csv = [{key_mapping.get(old_key): value for old_key, value in old_dict.items()} for old_dict in dados_csv] - list comprehension
new_dados_csv[0]
# Out:
# {'Nome do Produto': 'Lápis de sobrancelha',
#  'Categoria do Produto': 'Roupas',
#  'Preço do Produto (R$)': '55.17',
#  'Quantidade em Estoque': '62',
#  'Filial': 'Filial 1',
#  'Data da Venda': '2023-04-13 18:58:06.794203'}

# %%
combined_list = []
combined_list.extend(dados_json)
combined_list.extend(new_dados_csv)

len(combined_list)
# Out:
# 4446

# %%
nome_colunas = list(combined_list[0].keys())
nome_colunas
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial']

# %%
path_dados_combined = '../data_processed/dados_combinados.csv'

with open(path_dados_combined, 'w') as file:
    writer = csv.DictWriter(file, fieldnames=nome_colunas)
    writer.writeheader()

    for row in combined_list:
        writer.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 8
#       5 writer.writeheader()
#       7 for row in combined_list:
# ----> 8     writer.writerow(row)
#
# File /usr/lib/python3.10/csv.py:154, in DictWriter.writerow(self, rowdict)
#     153 def writerow(self, rowdict):
# --> 154     return self.writer.writerow(self._dict_to_list(rowdict))
#
# File /usr/lib/python3.10/csv.py:149, in DictWriter._dict_to_list(self, rowdict)
#     147     wrong_fields = rowdict.keys() - self.fieldnames
#     148     if wrong_fields:
# --> 149         raise ValueError("dict contains fields not in fieldnames: "
#     150                          + ", ".join([repr(x) for x in wrong_fields]))
#     151 return (rowdict.get(key, self.restval) for key in self.fieldnames)
#
# ValueError: dict contains fields not in fieldnames: 'Data da Venda'

# %%
nome_colunas = list(combined_list[-1].keys())
nome_colunas
# Out:
# ['Nome do Produto',
#  'Categoria do Produto',
#  'Preço do Produto (R$)',
#  'Quantidade em Estoque',
#  'Filial',
#  'Data da Venda']

# %%
dados_combinados_tabela = [nome_colunas]

for row in combined_list:
    linha = []
    for coluna in nome_colunas:
        linha.append(row.get(coluna, 'Indisponivel'))
    dados_combinados_tabela.append(linha)

# %%
path_dados_combinados = '../data_processed/dados_combinados.csv'

with open(path_dados_combinados, 'w') as file:
    writer = csv.writer(file)
    writer.writerows(dados_combinados_tabela)
